# %%
import pandas as pd
df1 = pd.read_csv("YoutubeResData/youtube480.csv")
df2 = pd.read_csv("YoutubeResData/youtube720.csv")
df3 = pd.read_csv("YoutubeResData/youtube1080.csv")

# %%
df1
# Out:
#              Time              IP1  Port1             IP2  Port2  Proto  \
# 0      1603518768   100.112.92.125   5353  100.112.95.158   5353     17
# 1      1603518768   100.112.81.137   8009  100.112.95.158  63763      6
# 2      1603518768  100.112.126.122   5353     224.0.0.251   5353     17
# 3      1603518768  100.112.113.229   5353     224.0.0.251   5353     17
# 4      1603518768   100.112.87.209   5353     224.0.0.251   5353     17
# ...           ...              ...    ...             ...    ...    ...
# 31683  1603519126   100.112.95.204   5353     224.0.0.251   5353     17
# 31684  1603519126   100.112.90.227   5353     224.0.0.251   5353     17
# 31685  1603519126   100.112.122.34   5353     224.0.0.251   5353     17
# 31686  1603519126   100.112.89.213   5353     224.0.0.251   5353     17
# 31687  1603519126     100.112.64.1      0     224.0.0.251      0      2
#
#        1->2Bytes  2->1Bytes  1->2Pkts  2->1Pkts  \
# 0              0        188         0         1
# ...

# %%
df2
# Out:
#              Time              IP1  Port1          IP2  Port2  Proto  \
# 0      1603519189    100.112.111.5   5353  224.0.0.251   5353     17
# 1      1603519189  100.112.127.106   5353  224.0.0.251   5353     17
# 2      1603519189    100.112.72.25   5353  224.0.0.251   5353     17
# 3      1603519189    100.112.95.37   5353  224.0.0.251   5353     17
# 4      1603519189    100.112.94.87   5353  224.0.0.251   5353     17
# ...           ...              ...    ...          ...    ...    ...
# 27755  1603519516  100.112.123.253   5353  224.0.0.251   5353     17
# 27756  1603519516   100.112.91.243   5353  224.0.0.251   5353     17
# 27757  1603519516   100.112.77.160   5353  224.0.0.251   5353     17
# 27758  1603519516  100.112.115.224   5353  224.0.0.251   5353     17
# 27759  1603519516  100.112.123.215   5353  224.0.0.251   5353     17
#
#        1->2Bytes  2->1Bytes  1->2Pkts  2->1Pkts    packet_times packet_sizes  \
# ...

# %%
df3
# Out:
#              Time              IP1  Port1          IP2  Port2  Proto  \
# 0      1603519549   100.112.112.42   5353  224.0.0.251   5353     17
# 1      1603519549   100.112.94.252   5353  224.0.0.251   5353     17
# 2      1603519549   100.112.124.88   5353  224.0.0.251   5353     17
# 3      1603519549   100.112.90.120   5353  224.0.0.251   5353     17
# 4      1603519549    100.112.94.87   5353  224.0.0.251   5353     17
# ...           ...              ...    ...          ...    ...    ...
# 29607  1603519902  100.112.112.205   5353  224.0.0.251   5353     17
# 29608  1603519902    100.112.79.69   5353  224.0.0.251   5353     17
# 29609  1603519902   100.112.74.132   5353  224.0.0.251   5353     17
# 29610  1603519902    100.112.73.73   5353  224.0.0.251   5353     17
# 29611  1603519902   100.112.91.132   5353  224.0.0.251   5353     17
#
#        1->2Bytes  2->1Bytes  1->2Pkts  2->1Pkts    packet_times packet_sizes  \
# ...

# %%
df1.plot(x='Time', y='1->2Bytes')
df1.plot(x='Time', y='2->1Bytes')

df2.plot(x='Time', y='1->2Bytes')
df2.plot(x='Time', y='2->1Bytes')

df3.plot(x='Time', y='1->2Bytes')
df3.plot(x='Time', y='2->1Bytes')

# %%
df1.plot(x='Time', y='1->2Pkts')
df1.plot(x='Time', y='2->1Pkts')

df2.plot(x='Time', y='1->2Pkts')
df2.plot(x='Time', y='2->1Pkts')

df3.plot(x='Time', y='1->2Pkts')
df3.plot(x='Time', y='2->1Pkts')

# %%
#df1.packet_sizes

# %%
df4 = pd.read_csv("OtherData/canvas_vpn.csv")
df5 = pd.read_csv("OtherData/netflix_vpn.csv")

# %%
df4.plot(x='Time', y='1->2Bytes')
df4.plot(x='Time', y='2->1Bytes')

df5.plot(x='Time', y='1->2Bytes')
df5.plot(x='Time', y='2->1Bytes')

# %%
df4.plot(x='Time', y='1->2Pkts')
df4.plot(x='Time', y='2->1Pkts')

df5.plot(x='Time', y='1->2Pkts')
df5.plot(x='Time', y='2->1Pkts')
